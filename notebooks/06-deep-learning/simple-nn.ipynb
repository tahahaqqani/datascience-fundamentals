# %% [markdown]
# # Your First Neural Network
#
# A minimal TensorFlow/Keras example: one neuron learns to double input values. Good warm-up before `neural-nets.ipynb` and `mnist-deep-learning.ipynb`.

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
# Sample data: Inputs and their double
X = np.array([1, 2, 3, 4, 5], dtype=float)
y = np.array([2, 4, 6, 8, 10], dtype=float)

# Build the model
model = keras.Sequential([
    keras.layers.Input(shape=(1,)),
    keras.layers.Dense(units=1),  # 1 neuron, 1 input
])

# Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# Train the model
model.fit(X, y, epochs=500, verbose=0)

# Test the model
print("Prediction for 10:", model.predict(np.array([10.0])))
